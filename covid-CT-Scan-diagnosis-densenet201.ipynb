# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.applications import DenseNet201

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '../input/sarscov2-ctscan-dataset'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                      File  DiseaseID Disease Type
# 0   COVID/Covid (230).png          0        COVID
# 1  COVID/Covid (1195).png          0        COVID
# 2   COVID/Covid (182).png          0        COVID
# 3   COVID/Covid (817).png          0        COVID
# 4   COVID/Covid (631).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                             File  DiseaseID Disease Type
# 0           COVID/Covid (54).png          0        COVID
# 1         COVID/Covid (1035).png          0        COVID
# 2   non-COVID/Non-Covid (21).png          1    non-COVID
# 3  non-COVID/Non-Covid (248).png          1    non-COVID
# 4          COVID/Covid (409).png          0        COVID

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 3, 3)

# %%
# Displays first n images of class from training set
plot_defects('non-COVID', 3, 3)

# %%
IMAGE_SIZE = 224
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2481it [00:32, 77.47it/s]
# Train Shape: (2481, 224, 224, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)
print(Y_train.shape)
# Out:
# (2481, 2)

# %%
BATCH_SIZE = 32

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
print(f'X_train:',X_train.shape)
print(f'X_val:',X_val.shape)
print(f'Y_train:',Y_train.shape)
print(f'Y_val:',Y_val.shape)
# Out:
# X_train: (1984, 224, 224, 3)
# X_val: (497, 224, 224, 3)
# Y_train: (1984, 2)
# Y_val: (497, 2)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 150
SIZE=224
N_ch=3

# %%
def build_resnet50():
    densetnet201 = DenseNet201(weights='imagenet', include_top=False)

    input = Input(shape=(224, 224, 3))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densetnet201(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.003, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_resnet50()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.70, patience=10, verbose=1, min_lr=1e-6)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=20, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        horizontal_flip=True) # Randomly flip inputs horizontally


datagen.fit(X_train)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 3)       84
# _________________________________________________________________
# densenet201 (Functional)     (None, None, None, 1920)  18321984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1920)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1920)              7680
# _________________________________________________________________
# dense (Dense)                (None, 128)               245888
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# _________________________________________________________________
# root (Dense)                 (None, 2)                 130
# =================================================================
# Total params: 18,584,790
# Trainable params: 18,351,510
# Non-trainable params: 233,280
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=32),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# Epoch 1/150
# 62/62 [==============================] - ETA: 0s - loss: 0.5618 - accuracy: 0.7434
# Epoch 00001: val_loss improved from inf to 0.73062, saving model to model.h5
# 62/62 [==============================] - 36s 574ms/step - loss: 0.5618 - accuracy: 0.7434 - val_loss: 0.7306 - val_accuracy: 0.5614
# Epoch 2/150
# 62/62 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8684
# Epoch 00002: val_loss did not improve from 0.73062
# 62/62 [==============================] - 29s 475ms/step - loss: 0.3151 - accuracy: 0.8684 - val_loss: 0.8943 - val_accuracy: 0.5594
# Epoch 3/150
# 62/62 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9057
# Epoch 00003: val_loss did not improve from 0.73062
# 62/62 [==============================] - 29s 466ms/step - loss: 0.2193 - accuracy: 0.9057 - val_loss: 1.1707 - val_accuracy: 0.5513
# Epoch 4/150
# 62/62 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9274
# Epoch 00004: val_loss did not improve from 0.73062
# 62/62 [==============================] - 29s 464ms/step - loss: 0.1853 - accuracy: 0.9274 - val_loss: 1.3532 - val_accuracy: 0.5976
# Epoch 5/150
# 62/62 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9360
# Epoch 00005: val_loss improved from 0.73062 to 0.52511, saving model to model.h5
# 62/62 [==============================] - 31s 497ms/step - loss: 0.1632 - accuracy: 0.9360 - val_loss: 0.5251 - val_accuracy: 0.7445
# Epoch 6/150
# 62/62 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9541
# Epoch 00006: val_loss improved from 0.52511 to 0.14221, saving model to model.h5
# 62/62 [==============================] - 31s 493ms/step - loss: 0.1182 - accuracy: 0.9541 - val_loss: 0.1422 - val_accuracy: 0.9336
# Epoch 7/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9632
# Epoch 00007: val_loss did not improve from 0.14221
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0965 - accuracy: 0.9632 - val_loss: 0.2771 - val_accuracy: 0.8994
# Epoch 8/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9768
# Epoch 00008: val_loss improved from 0.14221 to 0.14105, saving model to model.h5
# 62/62 [==============================] - 31s 498ms/step - loss: 0.0811 - accuracy: 0.9768 - val_loss: 0.1410 - val_accuracy: 0.9376
# Epoch 9/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9723
# Epoch 00009: val_loss improved from 0.14105 to 0.09918, saving model to model.h5
# 62/62 [==============================] - 31s 501ms/step - loss: 0.0815 - accuracy: 0.9723 - val_loss: 0.0992 - val_accuracy: 0.9678
# Epoch 10/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9783
# Epoch 00010: val_loss did not improve from 0.09918
# 62/62 [==============================] - 29s 470ms/step - loss: 0.0616 - accuracy: 0.9783 - val_loss: 0.1235 - val_accuracy: 0.9497
# Epoch 11/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9743
# Epoch 00011: val_loss did not improve from 0.09918
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0715 - accuracy: 0.9743 - val_loss: 0.2462 - val_accuracy: 0.9014
# Epoch 12/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9839
# Epoch 00012: val_loss did not improve from 0.09918
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0492 - accuracy: 0.9839 - val_loss: 0.2163 - val_accuracy: 0.9115
# Epoch 13/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9834
# Epoch 00013: val_loss did not improve from 0.09918
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0517 - accuracy: 0.9834 - val_loss: 0.2060 - val_accuracy: 0.9356
# Epoch 14/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9874
# Epoch 00014: val_loss did not improve from 0.09918
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0397 - accuracy: 0.9874 - val_loss: 0.1932 - val_accuracy: 0.9276
# Epoch 15/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9869
# Epoch 00015: val_loss did not improve from 0.09918
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0383 - accuracy: 0.9869 - val_loss: 0.3586 - val_accuracy: 0.8753
# Epoch 16/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9879
# Epoch 00016: val_loss improved from 0.09918 to 0.07387, saving model to model.h5
# 62/62 [==============================] - 31s 499ms/step - loss: 0.0416 - accuracy: 0.9879 - val_loss: 0.0739 - val_accuracy: 0.9738
# Epoch 17/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9889
# Epoch 00017: val_loss improved from 0.07387 to 0.06140, saving model to model.h5
# 62/62 [==============================] - 31s 499ms/step - loss: 0.0342 - accuracy: 0.9889 - val_loss: 0.0614 - val_accuracy: 0.9779
# Epoch 18/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9899
# Epoch 00018: val_loss did not improve from 0.06140
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.4884 - val_accuracy: 0.8410
# Epoch 19/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9894
# Epoch 00019: val_loss did not improve from 0.06140
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.1102 - val_accuracy: 0.9658
# Epoch 20/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9859
# Epoch 00020: val_loss did not improve from 0.06140
# 62/62 [==============================] - 29s 470ms/step - loss: 0.0406 - accuracy: 0.9859 - val_loss: 0.0666 - val_accuracy: 0.9678
# Epoch 21/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9864
# Epoch 00021: val_loss did not improve from 0.06140
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0412 - accuracy: 0.9864 - val_loss: 0.0912 - val_accuracy: 0.9598
# Epoch 22/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9879
# Epoch 00022: val_loss did not improve from 0.06140
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0393 - accuracy: 0.9879 - val_loss: 0.2403 - val_accuracy: 0.9437
# Epoch 23/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9889
# Epoch 00023: val_loss did not improve from 0.06140
# 62/62 [==============================] - 28s 455ms/step - loss: 0.0238 - accuracy: 0.9889 - val_loss: 0.0751 - val_accuracy: 0.9678
# Epoch 24/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9909
# Epoch 00024: val_loss improved from 0.06140 to 0.03316, saving model to model.h5
# 62/62 [==============================] - 31s 501ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.0332 - val_accuracy: 0.9920
# Epoch 25/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9955
# Epoch 00025: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0161 - accuracy: 0.9955 - val_loss: 0.0539 - val_accuracy: 0.9779
# Epoch 26/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9894
# Epoch 00026: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.1292 - val_accuracy: 0.9638
# Epoch 27/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9950
# Epoch 00027: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0826 - val_accuracy: 0.9759
# Epoch 28/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9955
# Epoch 00028: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.0856 - val_accuracy: 0.9557
# Epoch 29/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9950
# Epoch 00029: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0192 - accuracy: 0.9950 - val_loss: 0.0708 - val_accuracy: 0.9738
# Epoch 30/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9924
# Epoch 00030: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0184 - accuracy: 0.9924 - val_loss: 0.2055 - val_accuracy: 0.9135
# Epoch 31/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9975
# Epoch 00031: val_loss did not improve from 0.03316
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.0897 - val_accuracy: 0.9698
# Epoch 32/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9945
# Epoch 00032: val_loss improved from 0.03316 to 0.03069, saving model to model.h5
# 62/62 [==============================] - 30s 491ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0307 - val_accuracy: 0.9879
# Epoch 33/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9945
# Epoch 00033: val_loss did not improve from 0.03069
# 62/62 [==============================] - 28s 459ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.0438 - val_accuracy: 0.9819
# Epoch 34/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9904
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.002100000018253922.
#
# Epoch 00034: val_loss did not improve from 0.03069
# 62/62 [==============================] - 29s 469ms/step - loss: 0.0297 - accuracy: 0.9904 - val_loss: 0.1073 - val_accuracy: 0.9598
# Epoch 35/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9945
# Epoch 00035: val_loss did not improve from 0.03069
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.0820 - val_accuracy: 0.9718
# Epoch 36/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9950
# Epoch 00036: val_loss did not improve from 0.03069
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0339 - val_accuracy: 0.9899
# Epoch 37/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9980
# Epoch 00037: val_loss improved from 0.03069 to 0.02773, saving model to model.h5
# 62/62 [==============================] - 31s 501ms/step - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.0277 - val_accuracy: 0.9879
# Epoch 38/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9919
# Epoch 00038: val_loss did not improve from 0.02773
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.0349 - val_accuracy: 0.9859
# Epoch 39/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9929
# Epoch 00039: val_loss did not improve from 0.02773
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0159 - accuracy: 0.9929 - val_loss: 0.0813 - val_accuracy: 0.9698
# Epoch 40/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9970
# Epoch 00040: val_loss improved from 0.02773 to 0.00762, saving model to model.h5
# 62/62 [==============================] - 31s 507ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0076 - val_accuracy: 0.9980
# Epoch 41/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9985
# Epoch 00041: val_loss improved from 0.00762 to 0.00677, saving model to model.h5
# 62/62 [==============================] - 31s 495ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 42/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9990
# Epoch 00042: val_loss did not improve from 0.00677
# 62/62 [==============================] - 28s 458ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.0789 - val_accuracy: 0.9759
# Epoch 43/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9980
# Epoch 00043: val_loss did not improve from 0.00677
# 62/62 [==============================] - 28s 459ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.0606 - val_accuracy: 0.9759
# Epoch 44/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9980
# Epoch 00044: val_loss did not improve from 0.00677
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0218 - val_accuracy: 0.9940
# Epoch 45/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9945
# Epoch 00045: val_loss did not improve from 0.00677
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.1325 - val_accuracy: 0.9638
# Epoch 46/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9955
# Epoch 00046: val_loss improved from 0.00677 to 0.00519, saving model to model.h5
# 62/62 [==============================] - 31s 497ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 47/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9980
# Epoch 00047: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0095 - accuracy: 0.9980 - val_loss: 0.0197 - val_accuracy: 0.9899
# Epoch 48/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9975
# Epoch 00048: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0146 - val_accuracy: 0.9940
# Epoch 49/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9955
# Epoch 00049: val_loss did not improve from 0.00519
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.0220 - val_accuracy: 0.9879
# Epoch 50/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9980
# Epoch 00050: val_loss did not improve from 0.00519
# 62/62 [==============================] - 28s 455ms/step - loss: 0.0121 - accuracy: 0.9980 - val_loss: 0.3069 - val_accuracy: 0.8833
# Epoch 51/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9975
# Epoch 00051: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0192 - val_accuracy: 0.9940
# Epoch 52/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9985
# Epoch 00052: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 53/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9980
# Epoch 00053: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0164 - val_accuracy: 0.9940
# Epoch 54/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9965
# Epoch 00054: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0076 - accuracy: 0.9965 - val_loss: 0.0272 - val_accuracy: 0.9899
# Epoch 55/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9985
# Epoch 00055: val_loss did not improve from 0.00519
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0701 - val_accuracy: 0.9759
# Epoch 56/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9970
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0014699999475851653.
#
# Epoch 00056: val_loss did not improve from 0.00519
# 62/62 [==============================] - 28s 452ms/step - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.7632 - val_accuracy: 0.7465
# Epoch 57/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9965
# Epoch 00057: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0089 - accuracy: 0.9965 - val_loss: 0.0217 - val_accuracy: 0.9899
# Epoch 58/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9995
# Epoch 00058: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0106 - val_accuracy: 0.9960
# Epoch 59/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 00059: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0150 - val_accuracy: 0.9940
# Epoch 60/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9980
# Epoch 00060: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0114 - val_accuracy: 0.9920
# Epoch 61/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9940
# Epoch 62/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9940
# Epoch 63/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 00063: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0111 - val_accuracy: 0.9960
# Epoch 64/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9975
# Epoch 00064: val_loss did not improve from 0.00519
# 62/62 [==============================] - 28s 452ms/step - loss: 0.0051 - accuracy: 0.9975 - val_loss: 0.0585 - val_accuracy: 0.9799
# Epoch 65/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990
# Epoch 00065: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0296 - val_accuracy: 0.9899
# Epoch 66/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9995
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.0010289999307133257.
#
# Epoch 00066: val_loss did not improve from 0.00519
# 62/62 [==============================] - 29s 470ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0184 - val_accuracy: 0.9920
# Epoch 67/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9985
# Epoch 00067: val_loss improved from 0.00519 to 0.00497, saving model to model.h5
# 62/62 [==============================] - 31s 498ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0050 - val_accuracy: 0.9980
# Epoch 68/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9960
# Epoch 00068: val_loss did not improve from 0.00497
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0091 - accuracy: 0.9960 - val_loss: 0.0144 - val_accuracy: 0.9940
# Epoch 69/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9975
# Epoch 00069: val_loss did not improve from 0.00497
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0062 - accuracy: 0.9975 - val_loss: 0.0127 - val_accuracy: 0.9920
# Epoch 70/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00070: val_loss improved from 0.00497 to 0.00185, saving model to model.h5
# 62/62 [==============================] - 31s 499ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 71/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9995
# Epoch 00071: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0030 - val_accuracy: 0.9980
# Epoch 72/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00072: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0039 - val_accuracy: 0.9980
# Epoch 73/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 00073: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0873 - val_accuracy: 0.9738
# Epoch 74/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9990
# Epoch 00074: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 454ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0496 - val_accuracy: 0.9879
# Epoch 75/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 454ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9940
# Epoch 76/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.0007202999433502554.
#
# Epoch 00076: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0037 - val_accuracy: 0.9980
# Epoch 77/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9990
# Epoch 00077: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0041 - val_accuracy: 0.9980
# Epoch 78/150
# 62/62 [==============================] - ETA: 0s - loss: 9.6433e-04 - accuracy: 1.0000
# Epoch 00078: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 460ms/step - loss: 9.6433e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 79/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00079: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0046 - val_accuracy: 0.9980
# Epoch 80/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00080: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 81/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9980
# Epoch 00081: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.0129 - val_accuracy: 0.9960
# Epoch 82/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00082: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9980
# Epoch 83/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00083: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0070 - val_accuracy: 0.9960
# Epoch 84/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9990
# Epoch 00084: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 85/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9990
# Epoch 00085: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 457ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0033 - val_accuracy: 0.9980
# Epoch 86/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 0.0005042099684942513.
#
# Epoch 00086: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0030 - val_accuracy: 0.9980
# Epoch 87/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00087: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0044 - val_accuracy: 0.9980
# Epoch 88/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9995
# Epoch 00088: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9980
# Epoch 89/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9990
# Epoch 00089: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0073 - val_accuracy: 0.9980
# Epoch 90/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00090: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 468ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 91/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00091: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 92/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00092: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 93/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 00093: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 94/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00094: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 95/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9990
# Epoch 00095: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 454ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 96/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 0.0003529469657223671.
#
# Epoch 00096: val_loss did not improve from 0.00185
# 62/62 [==============================] - 28s 460ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 97/150
# 62/62 [==============================] - ETA: 0s - loss: 8.7618e-04 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 467ms/step - loss: 8.7618e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 98/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 99/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 00099: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 469ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 100/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9985
# Epoch 00100: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 468ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 101/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 00101: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0110 - val_accuracy: 0.9980
# Epoch 102/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00102: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 0.9980
# Epoch 103/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9995
# Epoch 00103: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 468ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 104/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9995
# Epoch 00104: val_loss did not improve from 0.00185
# 62/62 [==============================] - 29s 468ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 105/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 00105: val_loss improved from 0.00185 to 0.00180, saving model to model.h5
# 62/62 [==============================] - 31s 495ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 106/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 0.0002470628678565845.
#
# Epoch 00106: val_loss did not improve from 0.00180
# 62/62 [==============================] - 28s 458ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 107/150
# 62/62 [==============================] - ETA: 0s - loss: 8.3866e-04 - accuracy: 1.0000
# Epoch 00107: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 466ms/step - loss: 8.3866e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 108/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00108: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 109/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9995
# Epoch 00109: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 469ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 110/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00110: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 111/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00111: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 112/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00112: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 113/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00113: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 469ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 114/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00114: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 115/150
# 62/62 [==============================] - ETA: 0s - loss: 6.4930e-04 - accuracy: 1.0000
# Epoch 00115: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 466ms/step - loss: 6.4930e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 116/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 0.00017294401768594978.
#
# Epoch 00116: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 117/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00117: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 118/150
# 62/62 [==============================] - ETA: 0s - loss: 8.8004e-04 - accuracy: 1.0000
# Epoch 00118: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 466ms/step - loss: 8.8004e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 119/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00119: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 120/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 00120: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 121/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9990
# Epoch 00121: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 466ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 122/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00122: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 123/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00123: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 124/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00124: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 125/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9990
# Epoch 00125: val_loss did not improve from 0.00180
# 62/62 [==============================] - 28s 457ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 126/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 0.00012106080830562859.
#
# Epoch 00126: val_loss did not improve from 0.00180
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 127/150
# 62/62 [==============================] - ETA: 0s - loss: 5.9646e-04 - accuracy: 1.0000
# Epoch 00127: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 467ms/step - loss: 5.9646e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 128/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9985
# Epoch 00128: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 129/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00129: val_loss did not improve from 0.00180
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 130/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995
# Epoch 00130: val_loss improved from 0.00180 to 0.00173, saving model to model.h5
# 62/62 [==============================] - 31s 497ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 131/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9980
# Epoch 00131: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 465ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 132/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00132: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 133/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00133: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 463ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 134/150
# 62/62 [==============================] - ETA: 0s - loss: 7.9373e-04 - accuracy: 1.0000
# Epoch 00134: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 465ms/step - loss: 7.9373e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 135/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9975
# Epoch 00135: val_loss did not improve from 0.00173
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0041 - accuracy: 0.9975 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 136/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 8.474256683257408e-05.
#
# Epoch 00136: val_loss did not improve from 0.00173
# 62/62 [==============================] - 28s 459ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 137/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9995
# Epoch 00137: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 138/150
# 62/62 [==============================] - ETA: 0s - loss: 9.5639e-04 - accuracy: 1.0000
# Epoch 00138: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 463ms/step - loss: 9.5639e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 139/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00139: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 140/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00140: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 467ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 141/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 00141: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 142/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9990
# Epoch 00142: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 461ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 143/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00143: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 144/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9990
# Epoch 00144: val_loss did not improve from 0.00173
# 62/62 [==============================] - 28s 453ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 145/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00145: val_loss did not improve from 0.00173
# 62/62 [==============================] - 28s 456ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 146/150
# 62/62 [==============================] - ETA: 0s - loss: 7.3595e-04 - accuracy: 1.0000
# Epoch 00146: ReduceLROnPlateau reducing learning rate to 5.931979831075295e-05.
#
# Epoch 00146: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 465ms/step - loss: 7.3595e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 147/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00147: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 460ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 148/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00148: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 462ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 149/150
# 62/62 [==============================] - ETA: 0s - loss: 5.5134e-04 - accuracy: 1.0000
# Epoch 00149: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 470ms/step - loss: 5.5134e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 150/150
# 62/62 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00150: val_loss did not improve from 0.00173
# 62/62 [==============================] - 29s 464ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000

# %%
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 1s 82ms/step - loss: 0.0019 - accuracy: 1.0000
# Final Loss: 0.0018544222693890333, Final Accuracy: 1.0

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
'''FP = confusion_matrix.sum(axis=0) - np.diag(confusion_matrix)  
FN = confusion_matrix.sum(axis=1) - np.diag(confusion_matrix)
TP = np.diag(confusion_matrix)
TN = confusion_matrix.values.sum() - (FP + FN + TP)'''

TN = cm[0][0]
#print(TN)
FN = cm[1][0]
#print(FN)
TP = cm[1][1]
#print(TP)
FP = cm[0][1]
#print(FP)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
print(TPR)
# Specificity or true negative rate
TNR = TN/(TN+FP)
print(TNR)
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
print(FNR)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)
print(ACC)
# Out:
# 1.0
# 1.0
# 0.0
# 1.0

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
